# %% [markdown]
# # Gridworld walkthrough
#
# This notebook demonstrates the current ActiveBlockference API with deterministic local data and no external services.

# %%
from blockference import GridWorld, ExperimentConfig

world = GridWorld(3, {0: (0, 0)})
print(world.step({0: 3}))
config = ExperimentConfig.from_dict({"name": "notebook", "simulation": {"timesteps": 1}})
print(config.grid.dimension)
