# %% [markdown]
# # Single-agent inference model
#
# This notebook demonstrates the current ActiveBlockference API with deterministic local data and no external services.

# %%
from blockference import ActiveGridference, make_grid
from blockference.gridference import actinf_planning_single

agent = ActiveGridference(make_grid(3), planning_length=1)
agent.get_C((2, 2))
agent.get_D((0, 0))
update = actinf_planning_single(agent, agent.env_state, agent.A, agent.B, agent.C, agent.D)
print(update["update_action"], update["update_env"])
